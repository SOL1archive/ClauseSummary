# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
metric = pd.read_csv('./data/result/metric.csv')
metric.head()
# Out:
#        BLEU  ROUGE-Precision  ROUGE-Recall  ROUGE-F1
# 0  0.056486         0.000000      0.000000  0.000000
# 1  0.025258         0.000000      0.000000  0.000000
# 2  0.250962         0.037037      0.027778  0.031746
# 3  0.219148         0.029412      0.023529  0.026144
# 4  0.241610         0.102564      0.070175  0.083333

# %%
metric.describe().loc['mean']
# Out:
# BLEU               0.159251
# ROUGE-Precision    0.186452
# ROUGE-Recall       0.106466
# ROUGE-F1           0.127419
# Name: mean, dtype: float64

# %%
sns.set_style('darkgrid')

# %%
sns.kdeplot(metric[['BLEU']], shade=True, color='b', label='BLEU')
# Out:
# /tmp/ipykernel_26737/3180922990.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(metric[['BLEU']], shade=True, color='b', label='BLEU')
# <AxesSubplot: ylabel='Density'>

# %%
sns.histplot(metric[['BLEU']], bins=30)
# Out:
# <AxesSubplot: ylabel='Count'>
